# %% [markdown]
# # Recopilación de puntos

# %% [markdown]
# En esta sección vamos a comparar a la recopilación de puntos de cada equipo, vamos a comparar primero por temporadas y después la suma de todos.

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
#La información de estos datos pertenecen a la temporada 2017/2018 de La Liga. 
# Para ver como quedo la tabla de esta temporada vea dentro de la carpeta Info_para_usar y y abra la imagen que se llama 
#Tabla_temporada_2017_2018
Barcelona2018 = 93
AtleticoMadrid2018 = 79
RealMadrid2018 = 76
Valencia2018 = 73
Villareal2018 = 61
Betis2018 = 60
Sevilla2018 = 58 
#SIGUIENTES 6 EQUIPOS ->

#ULTIMOS 7 EQUIPOS ->

# %%
#La información de estos datos pertenecen a la temporada 2018/2019 de La Liga. 
# Para ver como quedo la tabla de esta temporada vea dentro de la carpeta Info_para_usar y y abra la imagen que se llama 
#Tabla_temporada_2018_2019
Barcelona2019 = 87
AtleticoMadrid2019 = 76
RealMadrid2019 = 68
Valencia2019 = 61
Getafe2019 = 59
Sevilla2019 = 59
Espanyol2019 = 53 
#SIGUIENTES 6 EQUIPOS ->

#ULTIMOS 7 EQUIPOS ->

# %%
#La información de estos datos pertenecen a la temporada 2019/2020 de La Liga. 
# Para ver como quedo la tabla de esta temporada vea dentro de la carpeta Info_para_usar y y abra la imagen que se llama 
#Tabla_temporada_2019_2020
Barcelona2020 = 58
RealMadrid2020 = 56
Sevilla2020 = 47
RealSociedad2020 = 46
Getafe2020 = 46
AtleticoMadrid2020 = 45
Valencia2020 = 42
#SIGUIENTES 6 EQUIPOS ->

#ULTIMOS 7 EQUIPOS ->

# %%
#Aquí vamos a sumar todas los puntos obtenidos por los equipos en estas temporadas y compararlos, primero sin sumarlos
#y luego todos sumados.
BarcelonaTOTAL = Barcelona2018 + Barcelona2019 + Barcelona2020
AtleticoMadridTOTAL = AtleticoMadrid2018 + AtleticoMadrid2019 + AtleticoMadrid2020 
RealMadridTOTAL = RealMadrid2018 + RealMadrid2019 + RealMadrid2020 
ValenciaTOTAL = Valencia2018 + Valencia2019 + Valencia2020 
VillarealTOTAL = Villareal2018 #AQUI FALTA LA DE 2019 y 2020 AHI LA PONE A QUIEN LE TOCO
BetisTOTAL = Betis2018 #AQUI FALTA LA DE 2019 y 2020 AHI LA PONE A QUIEN LE TOCO
SevillaTOTAL = Sevilla2018 + Sevilla2019 + Sevilla2020 

GetafeTOTAL = Getafe2019 + Getafe2020 #AQUI FALTA LA DE 2018 AHI LA PONE A QUIEN LE TOCO
EspanyolTOTAL = Espanyol2019 #AQUI FALTA LA DE 2018 y 2020 AHI LA PONE A QUIEN LE TOCO
RealSociedadTOTAL = RealSociedad2020 #AQUI FALTA LA DE 2018 y 2019 AHI LA PONE A QUIEN LE TOCO




indice = np.arange(10)
lista = [BarcelonaTOTAL, AtleticoMadridTOTAL, RealMadridTOTAL, ValenciaTOTAL, VillarealTOTAL, BetisTOTAL, SevillaTOTAL,
         GetafeTOTAL, EspanyolTOTAL, RealSociedadTOTAL]
plt.title("Comparación de las sumatorias de las 3 temporadas")
plt.xlabel("Equipo") 
plt.ylabel("Puntos")
y_pos = np.arange(len(lista))
plt.bar(y_pos, lista, color="r", align='center', alpha=0.5)
plt.xticks(indice, ("BAR", "ATM", "RMA", "VAL", "VIL", "BET", "SEV", "GET", "ESP", "REA"))
plt.show()

# %% [markdown]
# Para esta parte vamos a conocer el equipo mas campeón en cuando juega de Local, lo cúal es importante ya que es un factor que directamente afecta en el resultado según la creencia popular del Football. También vamos a ver el equipo mas goleador en su casa.

# %%
data = pd.read_csv('Info_para_usar\LaLiga Complete Matches 1995-2020.csv')
data.head(9245)
# Out:
#        Season        Date    HomeTeam     AwayTeam  FTHG  FTAG FTR  HTHG  \
# 0     1995-96    2/9/1995   La Coruna     Valencia     3     0   H   2.0
# 1     1995-96    2/9/1995    Sp Gijon     Albacete     3     0   H   3.0
# 2     1995-96    3/9/1995  Ath Bilbao    Santander     4     0   H   2.0
# 3     1995-96    3/9/1995  Ath Madrid     Sociedad     4     1   H   1.0
# 4     1995-96    3/9/1995       Celta   Compostela     0     1   A   0.0
# ...       ...         ...         ...          ...   ...   ...  ..   ...
# 9240  2018-19  24/04/2019     Levante        Betis     4     0   H   2.0
# 9241  2018-19  25/04/2019      Getafe  Real Madrid     0     0   D   0.0
# 9242  2018-19  25/04/2019     Sevilla    Vallecano     5     0   H   0.0
# 9243  2018-19  25/04/2019    Sociedad   Villarreal     0     1   A   0.0
# 9244  2018-19  27/04/2019  Ath Bilbao       Alaves     1     1   D   1.0
#
#       HTAG HTR
# 0      0.0   H
# 1      0.0   H
# 2      0.0   H
# 3      1.0   D
# 4      0.0   D
# ...    ...  ..
# 9240   0.0   H
# 9241   0.0   D
# 9242   0.0   D
# 9243   0.0   D
# 9244   1.0   D
#
# [9245 rows x 10 columns]

# %%
#BARCELONA RESULTADOS COMO LOCAL 
numero = 0 
BARvictories = 0 
BARdefeats = 0
BARdraw = 0
while(numero < 380):
    if(data.HomeTeam[8524 + numero] == 'Barcelona'):
        if(data.FTR[8524 + numero] == 'H'):
            BARvictories += 1
        elif(data.FTR[8524 + numero] == 'D'):
            BARdraw += 1
        elif(data.FTR[8524 + numero] == 'A'):
            BARdefeats += 1
    numero += 1
numero = 0 
while(numero < 380):
    if(data.HomeTeam[8904 + numero] == 'Barcelona'):
        if(data.FTR[8904 + numero] == 'H'):
            BARvictories += 1
        elif(data.FTR[8904 + numero] == 'D'):
            BARdraw += 1
        elif(data.FTR[8904 + numero] == 'A'):
            BARdefeats += 1
    numero += 1
numero = 0 
while(numero < 270):
    if(data.HomeTeam[9284 + numero] == 'Barcelona'):
        if(data.FTR[9284 + numero] == 'H'):
            BARvictories += 1
        elif(data.FTR[9284 + numero] == 'D'):
            BARdraw += 1
        elif(data.FTR[9284 + numero] == 'A'):
            BARdefeats += 1
    numero += 1
    
    
#ATLETICO DE MADRID RESULTADOS COMO LOCAL     
numero = 0 
ATMvictories = 0 
ATMdefeats = 0
ATMdraw = 0
while(numero < 380):
    if(data.HomeTeam[8524 + numero] == 'Ath Madrid'):
        if(data.FTR[8524 + numero] == 'H'):
            ATMvictories += 1
        elif(data.FTR[8524 + numero] == 'D'):
            ATMdraw += 1
        elif(data.FTR[8524 + numero] == 'A'):
            ATMdefeats += 1
    numero += 1
numero = 0 
while(numero < 380):
    if(data.HomeTeam[8904 + numero] == 'Ath Madrid'):
        if(data.FTR[8904 + numero] == 'H'):
            ATMvictories += 1
        elif(data.FTR[8904 + numero] == 'D'):
            ATMdraw += 1
        elif(data.FTR[8904 + numero] == 'A'):
            ATMdefeats += 1
    numero += 1
numero = 0 
while(numero < 270):
    if(data.HomeTeam[9284 + numero] == 'Ath Madrid'):
        if(data.FTR[9284 + numero] == 'H'):
            ATMvictories += 1
        elif(data.FTR[9284 + numero] == 'D'):
            ATMdraw += 1
        elif(data.FTR[9284 + numero] == 'A'):
            ATMdefeats += 1
    numero += 1


#REAL MADRID RESULTADOS COMO LOCAL     
numero = 0 
RMAvictories = 0 
RMAdefeats = 0
RMAdraw = 0
while(numero < 380):
    if(data.HomeTeam[8524 + numero] == "Real Madrid"):
        if(data.FTR[8524 + numero] == 'H'):
            RMAvictories += 1
        elif(data.FTR[8524 + numero] == 'D'):
            RMAdraw += 1
        elif(data.FTR[8524 + numero] == 'A'):
            RMAdefeats += 1
    numero += 1
numero = 0 
while(numero < 380):
    if(data.HomeTeam[8904 + numero] == "Real Madrid"):
        if(data.FTR[8904 + numero] == 'H'):
            RMAvictories += 1
        elif(data.FTR[8904 + numero] == 'D'):
            RMAdraw += 1
        elif(data.FTR[8904 + numero] == 'A'):
            RMAdefeats += 1
    numero += 1
numero = 0 
while(numero < 270):
    if(data.HomeTeam[9284 + numero] == "Real Madrid"):
        if(data.FTR[9284 + numero] == 'H'):
            RMAvictories += 1
        elif(data.FTR[9284 + numero] == 'D'):
            RMAdraw += 1
        elif(data.FTR[9284 + numero] == 'A'):
            RMAdefeats += 1
    numero += 1
    

#VALENCIA RESULTADOS COMO LOCAL     
numero = 0 
VALvictories = 0 
VALdefeats = 0
VALdraw = 0
while(numero < 380):
    if(data.HomeTeam[8524 + numero] == 'Valencia'):
        if(data.FTR[8524 + numero] == 'H'):
            VALvictories += 1
        elif(data.FTR[8524 + numero] == 'D'):
            VALdraw += 1
        elif(data.FTR[8524 + numero] == 'A'):
            VALdefeats += 1
    numero += 1
numero = 0 
while(numero < 380):
    if(data.HomeTeam[8904 + numero] == 'Valencia'):
        if(data.FTR[8904 + numero] == 'H'):
            VALvictories += 1
        elif(data.FTR[8904 + numero] == 'D'):
            VALdraw += 1
        elif(data.FTR[8904 + numero] == 'A'):
            VALdefeats += 1
    numero += 1
numero = 0 
while(numero < 270):
    if(data.HomeTeam[9284 + numero] == 'Valencia'):
        if(data.FTR[9284 + numero] == 'H'):
            VALvictories += 1
        elif(data.FTR[9284 + numero] == 'D'):
            VALdraw += 1
        elif(data.FTR[9284 + numero] == 'A'):
            VALdefeats += 1
    numero += 1
    
#VILLAREAL RESULTADOS COMO LOCAL     
numero = 0 
VILvictories = 0 
VILdefeats = 0
VILdraw = 0
while(numero < 380):
    if(data.HomeTeam[8524 + numero] == 'Villarreal'):
        if(data.FTR[8524 + numero] == 'H'):
            VILvictories += 1
        elif(data.FTR[8524 + numero] == 'D'):
            VILdraw += 1
        elif(data.FTR[8524 + numero] == 'A'):
            VILdefeats += 1
    numero += 1
numero = 0 
while(numero < 380):
    if(data.HomeTeam[8904 + numero] == 'Villarreal'):
        if(data.FTR[8904 + numero] == 'H'):
            VILvictories += 1
        elif(data.FTR[8904 + numero] == 'D'):
            VILdraw += 1
        elif(data.FTR[8904 + numero] == 'A'):
            VILdefeats += 1
    numero += 1
numero = 0 
while(numero < 270):
    if(data.HomeTeam[9284 + numero] == 'Villarreal'):
        if(data.FTR[9284 + numero] == 'H'):
            VILvictories += 1
        elif(data.FTR[9284 + numero] == 'D'):
            VILdraw += 1
        elif(data.FTR[9284 + numero] == 'A'):
            VILdefeats += 1
    numero += 1
    

#REAL BETIS RESULTADOS COMO LOCAL     
numero = 0 
BETvictories = 0 
BETdefeats = 0
BETdraw = 0
while(numero < 380):
    if(data.HomeTeam[8524 + numero] == 'Betis'):
        if(data.FTR[8524 + numero] == 'H'):
            BETvictories += 1
        elif(data.FTR[8524 + numero] == 'D'):
            BETdraw += 1
        elif(data.FTR[8524 + numero] == 'A'):
            BETdefeats += 1
    numero += 1
numero = 0 
while(numero < 380):
    if(data.HomeTeam[8904 + numero] == 'Betis'):
        if(data.FTR[8904 + numero] == 'H'):
            BETvictories += 1
        elif(data.FTR[8904 + numero] == 'D'):
            BETdraw += 1
        elif(data.FTR[8904 + numero] == 'A'):
            BETdefeats += 1
    numero += 1
numero = 0 
while(numero < 270):
    if(data.HomeTeam[9284 + numero] == 'Betis'):
        if(data.FTR[9284 + numero] == 'H'):
            BETvictories += 1
        elif(data.FTR[9284 + numero] == 'D'):
            BETdraw += 1
        elif(data.FTR[9284 + numero] == 'A'):
            BETdefeats += 1
    numero += 1
    

#SEVILLA RESULTADOS COMO LOCAL     
numero = 0 
SEVvictories = 0 
SEVdefeats = 0
SEVdraw = 0
while(numero < 380):
    if(data.HomeTeam[8524 + numero] == 'Sevilla'):
        if(data.FTR[8524 + numero] == 'H'):
            SEVvictories += 1
        elif(data.FTR[8524 + numero] == 'D'):
            SEVdraw += 1
        elif(data.FTR[8524 + numero] == 'A'):
            SEVdefeats += 1
    numero += 1
numero = 0 
while(numero < 380):
    if(data.HomeTeam[8904 + numero] == 'Sevilla'):
        if(data.FTR[8904 + numero] == 'H'):
            SEVvictories += 1
        elif(data.FTR[8904 + numero] == 'D'):
            SEVdraw += 1
        elif(data.FTR[8904 + numero] == 'A'):
            SEVdefeats += 1
    numero += 1
numero = 0 
while(numero < 270):
    if(data.HomeTeam[9284 + numero] == 'Sevilla'):
        if(data.FTR[9284 + numero] == 'H'):
            SEVvictories += 1
        elif(data.FTR[9284 + numero] == 'D'):
            SEVdraw += 1
        elif(data.FTR[9284 + numero] == 'A'):
            SEVdefeats += 1
    numero += 1

    
#GETAFE RESULTADOS COMO LOCAL     
numero = 0 
GETvictories = 0 
GETdefeats = 0
GETdraw = 0
while(numero < 380):
    if(data.HomeTeam[8524 + numero] == 'Getafe'):
        if(data.FTR[8524 + numero] == 'H'):
            GETvictories += 1
        elif(data.FTR[8524 + numero] == 'D'):
            GETdraw += 1
        elif(data.FTR[8524 + numero] == 'A'):
            GETdefeats += 1
    numero += 1
numero = 0 
while(numero < 380):
    if(data.HomeTeam[8904 + numero] == 'Getafe'):
        if(data.FTR[8904 + numero] == 'H'):
            GETvictories += 1
        elif(data.FTR[8904 + numero] == 'D'):
            GETdraw += 1
        elif(data.FTR[8904 + numero] == 'A'):
            GETdefeats += 1
    numero += 1
numero = 0 
while(numero < 270):
    if(data.HomeTeam[9284 + numero] == 'Getafe'):
        if(data.FTR[9284 + numero] == 'H'):
            GETvictories += 1
        elif(data.FTR[9284 + numero] == 'D'):
            GETdraw += 1
        elif(data.FTR[9284 + numero] == 'A'):
            GETdefeats += 1
    numero += 1
    
    
#REAL ESPANYOL RESULTADOS COMO LOCAL     
numero = 0 
ESPvictories = 0 
ESPdefeats = 0
ESPdraw = 0
while(numero < 380):
    if(data.HomeTeam[8524 + numero] == 'Espanol'):
        if(data.FTR[8524 + numero] == 'H'):
            ESPvictories += 1
        elif(data.FTR[8524 + numero] == 'D'):
            ESPdraw += 1
        elif(data.FTR[8524 + numero] == 'A'):
            ESPdefeats += 1
    numero += 1
numero = 0 
while(numero < 380):
    if(data.HomeTeam[8904 + numero] == 'Espanol'):
        if(data.FTR[8904 + numero] == 'H'):
            ESPvictories += 1
        elif(data.FTR[8904 + numero] == 'D'):
            ESPdraw += 1
        elif(data.FTR[8904 + numero] == 'A'):
            ESPdefeats += 1
    numero += 1
numero = 0 
while(numero < 270):
    if(data.HomeTeam[9284 + numero] == 'Espanol'):
        if(data.FTR[9284 + numero] == 'H'):
            ESPvictories += 1
        elif(data.FTR[9284 + numero] == 'D'):
            ESPdraw += 1
        elif(data.FTR[9284 + numero] == 'A'):
            ESPdefeats += 1
    numero += 1
    
#REAL SOCIEDAD RESULTADOS COMO LOCAL     
numero = 0 
REAvictories = 0 
REAdefeats = 0
REAdraw = 0
while(numero < 380):
    if(data.HomeTeam[8524 + numero] == 'Sociedad'):
        if(data.FTR[8524 + numero] == 'H'):
            REAvictories += 1
        elif(data.FTR[8524 + numero] == 'D'):
            REAdraw += 1
        elif(data.FTR[8524 + numero] == 'A'):
            REAdefeats += 1
    numero += 1
numero = 0 
while(numero < 380):
    if(data.HomeTeam[8904 + numero] == 'Sociedad'):
        if(data.FTR[8904 + numero] == 'H'):
            REAvictories += 1
        elif(data.FTR[8904 + numero] == 'D'):
            REAdraw += 1
        elif(data.FTR[8904 + numero] == 'A'):
            REAdefeats += 1
    numero += 1
numero = 0 
while(numero < 270):
    if(data.HomeTeam[9284 + numero] == 'Sociedad'):
        if(data.FTR[9284 + numero] == 'H'):
            REAvictories += 1
        elif(data.FTR[9284 + numero] == 'D'):
            REAdraw += 1
        elif(data.FTR[9284 + numero] == 'A'):
            REAdefeats += 1
    numero += 1
print('Victorias del REAL SOCIEDAD como Local: '+ str(REAvictories))
print('Derrotas del REAL SOCIEDAD como Local: '+ str(REAdefeats))
print('Empates del REAL SOCIEDAD como Local: '+ str(REAdraw))
# Out:
# Victorias del REAL SOCIEDAD como Local: 25
# Derrotas del REAL SOCIEDAD como Local: 15
# Empates del REAL SOCIEDAD como Local: 11

# %%
indice = np.arange(10)
lista = [atletico_mean, sociedad_mean]
plt.title("Rendimientos como local de las 3 temporadas")
plt.xlabel("Equipo") 
plt.ylabel("Puntos")
y_pos = np.arange(len(lista))
plt.bar(y_pos, lista, align='center', alpha=0.5)
plt.xticks(indice, ("BAR", "ATM", "RMA", "VAL", "VIL", "BET", "SEV", "GET", "ESP", "REA"))
plt.show()

# %%
import plotly.graph_objects as go

x=['BAR', 'ATM', 'RMA', 'VAL']
fig = go.Figure(go.Bar(x=x, y=[BARvictories, ATMvictories, RMAvictories, VALvictories], name='Victorias'))
fig.add_trace(go.Bar(x=x, y=[BARdraw, ATMdraw, RMAdraw, VALdraw], name='Empates'))
fig.add_trace(go.Bar(x=x, y=[BARdefeats, ATMdefeats, RMAdefeats, VALdefeats,], name='Derrotas'))

fig.update_layout(barmode='stack', xaxis={'categoryorder':'total descending'})
fig.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-29-90dbda23797a> in <module>
# ----> 1 import plotly.graph_objects as go
#       2
#       3 x=['BAR', 'ATM', 'RMA', 'VAL']
#       4 fig = go.Figure(go.Bar(x=x, y=[BARvictories, ATMvictories, RMAvictories, VALvictories], name='Victorias'))
#       5 fig.add_trace(go.Bar(x=x, y=[BARdraw, ATMdraw, RMAdraw, VALdraw], name='Empates'))
#
# ModuleNotFoundError: No module named 'plotly'
