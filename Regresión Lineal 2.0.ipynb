# %% [markdown]
# # Regresión Lineal

# %%
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt
# %matplotlib inline
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
plt.rcParams['figure.figsize'] = (16, 9)
plt.style.use('ggplot')
from sklearn import linear_model
from sklearn.metrics import mean_squared_error, r2_score

# %%
import import_ipynb

# %%
import io, os, sys, types
from IPython import get_ipython
from nbformat import read
from IPython.core.interactiveshell import InteractiveShell

# %%
import AnalisisExploratorio as liga

# %%
data = pd.read_csv('Info_para_usar\LaLiga Complete Matches 1995-2020.csv')

# %%
X = []
y = []
REAX = []
REAy = []

# %%
'''
numero = 0 
BARvictories = 0 
BARdefeats = 0
BARdraw = 0
while(numero < 380):
    if(data.HomeTeam[8524 + numero] == 'Barcelona'):
        if(data.FTR[8524 + numero] == 'H'):
            BARvictories += 3
            BARdefeats += 3
            y.append(BARvictories)
            X.append(BARdefeats)
        elif(data.FTR[8524 + numero] == 'D'):
            BARvictories += 1
            BARdefeats += 3
            y.append(BARvictories)
            X.append(BARdefeats)
        elif(data.FTR[8524 + numero] == 'A'):
            BARdefeats += 3
            BARvictories += 0
            X.append(BARdefeats)
            y.append(BARvictories)
    numero += 1
numero = 0 
while(numero < 380):
    if(data.HomeTeam[8904 + numero] == 'Barcelona'):
        if(data.FTR[8904 + numero] == 'H'):
            BARvictories += 3
            BARdefeats += 3
            y.append(BARvictories)
            X.append(BARdefeats)
        elif(data.FTR[8904 + numero] == 'D'):
            BARvictories += 1
            BARdefeats += 3
            y.append(BARvictories)
            X.append(BARdefeats)
        elif(data.FTR[8904 + numero] == 'A'):
            BARdefeats += 3
            BARvictories += 0
            X.append(BARdefeats)
            y.append(BARvictories)
    numero += 1
numero = 0 
while(numero < 270):
    if(data.HomeTeam[9284 + numero] == 'Barcelona'):
        if(data.FTR[9284 + numero] == 'H'):
            BARvictories += 3
            BARdefeats += 3
            y.append(BARvictories)
            X.append(BARdefeats)
        elif(data.FTR[9284 + numero] == 'D'):
            BARvictories += 1
            BARdefeats += 3
            y.append(BARvictories)
            X.append(BARdefeats)
        elif(data.FTR[9284 + numero] == 'A'):
            BARdefeats += 3
            BARvictories += 0
            X.append(BARdefeats)
            y.append(BARvictories)
    numero += 1 
'''
'''
numero = 0 
ATMvictories = 0 
ATMdefeats = 0
ATMdraw = 0
while(numero < 380):
    if(data.HomeTeam[8524 + numero] == 'Ath Madrid'):
        if(data.FTR[8524 + numero] == 'H'):
            ATMdefeats += 3
            ATMvictories += 3
            X.append(ATMdefeats)
            y.append(ATMvictories)
        elif(data.FTR[8524 + numero] == 'D'):
            ATMdefeats += 3
            ATMvictories += 1
            X.append(ATMdefeats)
            y.append(ATMvictories)
        elif(data.FTR[8524 + numero] == 'A'):
            ATMdefeats += 3
            ATMvictories += 0
            X.append(ATMdefeats)
            y.append(ATMvictories)
    numero += 1
numero = 0 
while(numero < 380):
    if(data.HomeTeam[8904 + numero] == 'Ath Madrid'):
        if(data.FTR[8904 + numero] == 'H'):
            ATMdefeats += 3
            ATMvictories += 3
            X.append(ATMdefeats)
            y.append(ATMvictories)
        elif(data.FTR[8904 + numero] == 'D'):
            ATMdefeats += 3
            ATMvictories += 1
            X.append(ATMdefeats)
            y.append(ATMvictories)
        elif(data.FTR[8904 + numero] == 'A'):
            ATMdefeats += 3
            ATMvictories += 0
            X.append(ATMdefeats)
            y.append(ATMvictories)
    numero += 1
numero = 0 
while(numero < 270):
    if(data.HomeTeam[9284 + numero] == 'Ath Madrid'):
        if(data.FTR[9284 + numero] == 'H'):
            ATMdefeats += 3
            ATMvictories += 3
            X.append(ATMdefeats)
            y.append(ATMvictories)
        elif(data.FTR[9284 + numero] == 'D'):
            ATMdefeats += 3
            ATMvictories += 1
            X.append(ATMdefeats)
            y.append(ATMvictories)
        elif(data.FTR[9284 + numero] == 'A'):
            ATMdefeats += 3
            ATMvictories += 0
            X.append(ATMdefeats)
            y.append(ATMvictories)
    numero += 1
'''   
   
"""
numero = 0 
RMAvictories = 0 
RMAdefeats = 0
RMAdraw = 0
while(numero < 380):
    if(data.HomeTeam[8524 + numero] == "Real Madrid"):
        if(data.FTR[8524 + numero] == 'H'):
            RMAdefeats += 3
            RMAvictories += 3
            X.append(RMAdefeats)
            y.append(RMAvictories)
        elif(data.FTR[8524 + numero] == 'D'):
            RMAdefeats += 3
            RMAvictories += 1
            X.append(RMAdefeats)
            y.append(RMAvictories)
        elif(data.FTR[8524 + numero] == 'A'):
            RMAdefeats += 3
            RMAvictories += 0
            X.append(RMAdefeats)
            y.append(RMAvictories)
    numero += 1
numero = 0 
while(numero < 380):
    if(data.HomeTeam[8904 + numero] == "Real Madrid"):
        if(data.FTR[8904 + numero] == 'H'):
            RMAdefeats += 3
            RMAvictories += 3
            X.append(RMAdefeats)
            y.append(RMAvictories)
        elif(data.FTR[8904 + numero] == 'D'):
            RMAdefeats += 3
            RMAvictories += 1
            X.append(RMAdefeats)
            y.append(RMAvictories)
        elif(data.FTR[8904 + numero] == 'A'):
            RMAdefeats += 3
            RMAvictories += 0
            X.append(RMAdefeats)
            y.append(RMAvictories)
    numero += 1
numero = 0 
while(numero < 270):
    if(data.HomeTeam[9284 + numero] == "Real Madrid"):
        if(data.FTR[9284 + numero] == 'H'):
            RMAdefeats += 3
            RMAvictories += 3
            X.append(RMAdefeats)
            y.append(RMAvictories)
        elif(data.FTR[9284 + numero] == 'D'):
            RMAdefeats += 3
            RMAvictories += 1
            X.append(RMAdefeats)
            y.append(RMAvictories)
        elif(data.FTR[9284 + numero] == 'A'):
            RMAdefeats += 3
            RMAvictories += 0
            X.append(RMAdefeats)
            y.append(RMAvictories)
    numero += 1
"""
 
'''
#VALENCIA RESULTADOS COMO LOCAL     
numero = 0 
VALvictories = 0 
VALdefeats = 0
VALdraw = 0
while(numero < 380):
    if(data.HomeTeam[8524 + numero] == 'Valencia'):
        if(data.FTR[8524 + numero] == 'H'):
            VALdefeats += 3
            VALvictories += 3
            X.append(VALdefeats)
            y.append(VALvictories)
        elif(data.FTR[8524 + numero] == 'D'):
            VALdefeats += 3
            VALvictories += 1
            X.append(VALdefeats)
            y.append(VALvictories)
        elif(data.FTR[8524 + numero] == 'A'):
            VALdefeats += 3
            VALvictories += 0
            X.append(VALdefeats)
            y.append(VALvictories)
    numero += 1
numero = 0 
while(numero < 380):
    if(data.HomeTeam[8904 + numero] == 'Valencia'):
        if(data.FTR[8904 + numero] == 'H'):
            VALdefeats += 3
            VALvictories += 3
            X.append(VALdefeats)
            y.append(VALvictories)
        elif(data.FTR[8904 + numero] == 'D'):
            VALdefeats += 3
            VALvictories += 1
            X.append(VALdefeats)
            y.append(VALvictories)
        elif(data.FTR[8904 + numero] == 'A'):
            VALdefeats += 3
            VALvictories += 0
            X.append(VALdefeats)
            y.append(VALvictories)
    numero += 1
numero = 0 
while(numero < 270):
    if(data.HomeTeam[9284 + numero] == 'Valencia'):
        if(data.FTR[9284 + numero] == 'H'):
            VALdefeats += 3
            VALvictories += 3
            X.append(VALdefeats)
            y.append(VALvictories)
        elif(data.FTR[9284 + numero] == 'D'):
            VALdefeats += 3
            VALvictories += 1
            X.append(VALdefeats)
            y.append(VALvictories)
        elif(data.FTR[9284 + numero] == 'A'):
            VALdefeats += 3
            VALvictories += 0
            X.append(VALdefeats)
            y.append(VALvictories)
    numero += 1
'''


#VILLAREAL RESULTADOS COMO LOCAL     
numero = 0 
VILvictories = 0 
VILdefeats = 0
VILdraw = 0
while(numero < 380):
    if(data.HomeTeam[8524 + numero] == 'Villarreal'):
        if(data.FTR[8524 + numero] == 'H'):
            VILdefeats += 3
            VILvictories += 3
            X.append(VILdefeats)
            y.append(VILvictories)
        elif(data.FTR[8524 + numero] == 'D'):
            VILdefeats += 3
            VILvictories += 1
            X.append(VILdefeats)
            y.append(VILvictories)
        elif(data.FTR[8524 + numero] == 'A'):
            VILdefeats += 3
            VILvictories += 0
            X.append(VILdefeats)
            y.append(VILvictories)
    numero += 1
numero = 0 
while(numero < 380):
    if(data.HomeTeam[8904 + numero] == 'Villarreal'):
        if(data.FTR[8904 + numero] == 'H'):
            VILdefeats += 3
            VILvictories += 3
            X.append(VILdefeats)
            y.append(VILvictories)
        elif(data.FTR[8904 + numero] == 'D'):
            VILdefeats += 3
            VILvictories += 1
            X.append(VILdefeats)
            y.append(VILvictories)
        elif(data.FTR[8904 + numero] == 'A'):
            VILdefeats += 3
            VILvictories += 0
            X.append(VILdefeats)
            y.append(VILvictories)
    numero += 1
numero = 0 
while(numero < 270):
    if(data.HomeTeam[9284 + numero] == 'Villarreal'):
        if(data.FTR[9284 + numero] == 'H'):
            VILdefeats += 3
            VILvictories += 3
            X.append(VILdefeats)
            y.append(VILvictories)
        elif(data.FTR[9284 + numero] == 'D'):
            VILdefeats += 3
            VILvictories += 1
            X.append(VILdefeats)
            y.append(VILvictories)
        elif(data.FTR[9284 + numero] == 'A'):
            VILdefeats += 3
            VILvictories += 0
            X.append(VILdefeats)
            y.append(VILvictories)
    numero += 1


'''
#REAL BETIS RESULTADOS COMO LOCAL     
numero = 0 
BETvictories = 0 
BETdefeats = 0
BETdraw = 0
while(numero < 380):
    if(data.HomeTeam[8524 + numero] == 'Betis'):
        if(data.FTR[8524 + numero] == 'H'):
            BETdefeats += 3
            BETvictories += 3
            X.append(BETdefeats)
            y.append(BETvictories)
        elif(data.FTR[8524 + numero] == 'D'):
            BETdefeats += 3
            BETvictories += 1
            X.append(BETdefeats)
            y.append(BETvictories)
        elif(data.FTR[8524 + numero] == 'A'):
            BETdefeats += 3
            BETvictories += 0
            X.append(BETdefeats)
            y.append(BETvictories)
    numero += 1
numero = 0 
while(numero < 380):
    if(data.HomeTeam[8904 + numero] == 'Betis'):
        if(data.FTR[8904 + numero] == 'H'):
            BETdefeats += 3
            BETvictories += 3
            X.append(BETdefeats)
            y.append(BETvictories)
        elif(data.FTR[8904 + numero] == 'D'):
            BETdefeats += 3
            BETvictories += 1
            X.append(BETdefeats)
            y.append(BETvictories)
        elif(data.FTR[8904 + numero] == 'A'):
            BETdefeats += 3
            BETvictories += 0
            X.append(BETdefeats)
            y.append(BETvictories)
    numero += 1
numero = 0 
while(numero < 270):
    if(data.HomeTeam[9284 + numero] == 'Betis'):
        if(data.FTR[9284 + numero] == 'H'):
            BETdefeats += 3
            BETvictories += 3
            X.append(BETdefeats)
            y.append(BETvictories)
        elif(data.FTR[9284 + numero] == 'D'):
            BETdefeats += 3
            BETvictories += 1
            X.append(BETdefeats)
            y.append(BETvictories)
        elif(data.FTR[9284 + numero] == 'A'):
            BETdefeats += 3
            BETvictories += 0
            X.append(BETdefeats)
            y.append(BETvictories)
    numero += 1
'''


"""
#SEVILLA RESULTADOS COMO LOCAL     
numero = 0 
SEVvictories = 0 
SEVdefeats = 0
SEVdraw = 0
while(numero < 380):
    if(data.HomeTeam[8524 + numero] == 'Sevilla'):
        if(data.FTR[8524 + numero] == 'H'):
            SEVdefeats += 3
            SEVvictories += 3
            X.append(BETdefeats)
            y.append(BETvictories)
        elif(data.FTR[8524 + numero] == 'D'):
            SEVdefeats += 3
            SEVvictories += 1
            X.append(SEVdefeats)
            y.append(SEVvictories)
        elif(data.FTR[8524 + numero] == 'A'):
            SEVdefeats += 3
            SEVvictories += 0
            X.append(SEVdefeats)
            y.append(SEVvictories)
    numero += 1
numero = 0 
while(numero < 380):
    if(data.HomeTeam[8904 + numero] == 'Sevilla'):
        if(data.FTR[8904 + numero] == 'H'):
            SEVdefeats += 3
            SEVvictories += 3
            X.append(SEVdefeats)
            y.append(SEVvictories)
        elif(data.FTR[8904 + numero] == 'D'):
            SEVdefeats += 3
            SEVvictories += 1
            X.append(SEVdefeats)
            y.append(SEVvictories)
        elif(data.FTR[8904 + numero] == 'A'):
            SEVdefeats += 3
            SEVvictories += 0
            X.append(SEVdefeats)
            y.append(SEVvictories)
    numero += 1
numero = 0 
while(numero < 270):
    if(data.HomeTeam[9284 + numero] == 'Sevilla'):
        if(data.FTR[9284 + numero] == 'H'):
            SEVdefeats += 3
            SEVvictories += 3
            X.append(SEVdefeats)
            y.append(SEVvictories)
        elif(data.FTR[9284 + numero] == 'D'):
            SEVdefeats += 3
            SEVvictories += 1
            X.append(SEVdefeats)
            y.append(SEVvictories)
        elif(data.FTR[9284 + numero] == 'A'):
            SEVdefeats += 3
            SEVvictories += 0
            X.append(SEVdefeats)
            y.append(SEVvictories)
    numero += 1
"""

''' 
#REAL SOCIEDAD RESULTADOS COMO LOCAL     
numero = 0 
REAvictories = 0 
REAdefeats = 0
REAdraw = 0
while(numero < 380):
    if(data.HomeTeam[8524 + numero] == 'Sociedad'):
        if(data.FTR[8524 + numero] == 'H'):
            REAdefeats += 3
            REAvictories += 3
            X.append(REAdefeats)
            y.append(REAvictories)
        elif(data.FTR[8524 + numero] == 'D'):
            REAdefeats += 3
            REAvictories += 1
            X.append(REAdefeats)
            y.append(REAvictories)
        elif(data.FTR[8524 + numero] == 'A'):
            REAdefeats += 3
            REAvictories += 0
            X.append(REAdefeats)
            y.append(REAvictories)
    numero += 1
numero = 0 
while(numero < 380):
    if(data.HomeTeam[8904 + numero] == 'Sociedad'):
        if(data.FTR[8904 + numero] == 'H'):
            REAdefeats += 3
            REAvictories += 3
            X.append(REAdefeats)
            y.append(REAvictories)
        elif(data.FTR[8904 + numero] == 'D'):
            REAdefeats += 3
            REAvictories += 1
            X.append(REAdefeats)
            y.append(REAvictories)
        elif(data.FTR[8904 + numero] == 'A'):
            REAdefeats += 3
            REAvictories += 0
            X.append(REAdefeats)
            y.append(REAvictories)
    numero += 1
numero = 0 
while(numero < 270):
    if(data.HomeTeam[9284 + numero] == 'Sociedad'):
        if(data.FTR[9284 + numero] == 'H'):
            REAdefeats += 3
            REAvictories += 3
            X.append(REAdefeats)
            y.append(REAvictories)
        elif(data.FTR[9284 + numero] == 'D'):
            REAdefeats += 3
            REAvictories += 1
            X.append(REAdefeats)
            y.append(REAvictories)
        elif(data.FTR[9284 + numero] == 'A'):
            REAdefeats += 3
            REAvictories += 0
            X.append(REAdefeats)
            y.append(REAvictories)
    numero += 1
'''    
 

print('6')
# Out:
# 6

# %%
X.append(156)
y.append(82)
X.append(159)
y.append(85)
X.append(162)
y.append(86)
X.append(165)
y.append(89)
X.append(168)
y.append(89)
X.append(171)
y.append(89)
X.append(174)
y.append(90)
X.append(177)
y.append(90)
X.append(180)
y.append(93)
X.append(180)
y.append(93)
print(X)
print(y)
# Out:
# [3, 6, 9, 12, 15, 18, 21, 24, 27, 30, 33, 36, 39, 42, 45, 48, 51, 54, 57, 60, 63, 66, 69, 72, 75, 78, 81, 84, 87, 90, 93, 96, 99, 102, 105, 108, 111, 114, 117, 120, 123, 126, 129, 132, 135, 138, 141, 144, 147, 150, 153, 156, 159, 162, 165, 168, 171, 174, 177, 180]
# [3, 4, 7, 10, 13, 13, 13, 14, 17, 20, 20, 23, 23, 26, 26, 29, 32, 35, 36, 36, 36, 37, 37, 38, 39, 42, 42, 43, 43, 44, 45, 48, 48, 51, 52, 55, 56, 59, 60, 61, 64, 67, 70, 71, 71, 72, 75, 75, 78, 81, 81, 82, 85, 86, 89, 89, 89, 90, 90, 93]

# %%
# Splitting the dataset into the Training set and Test set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %%
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
X_train = sc_X.fit_transform(np.array(X_train).reshape(-1,1))
X_test = sc_X.transform(np.array(X_test).reshape(-1,1))

# %%
X = np.array(X).reshape(-1,1)
y = np.array(y).reshape(-1,1)

# %%
# Fitting Linear Regression to the dataset
from sklearn.linear_model import LinearRegression
lin_reg = LinearRegression()
lin_reg.fit(X, y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
# Fitting Polynomial Regression to the dataset
from sklearn.preprocessing import PolynomialFeatures
poly_reg = PolynomialFeatures(degree = 4)
X_poly = poly_reg.fit_transform(X)
poly_reg.fit(X_poly, y)
lin_reg_2 = LinearRegression()
lin_reg_2.fit(X_poly, y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
# Visualising the Linear Regression results
plt.scatter(X, y, color = 'red')
plt.plot(X, lin_reg.predict(X), color = 'blue')
plt.title('Truth or Bluff (Linear Regression)')
plt.xlabel('points earned')
plt.ylabel('points obtained')
plt.show()

# %%
# Visualising the Polynomial Regression results
plt.scatter(X, y, color = 'red')
plt.plot(X, lin_reg_2.predict(poly_reg.fit_transform(X)), color = 'blue')
plt.title('Truth or Bluff (Polynomial Regression)')
plt.xlabel('points earned')
plt.ylabel('points obtained')
plt.show()

# %%
# Visualising the Polynomial Regression results (for higher resolution and smoother curve)
X_grid = np.arange(min(X), max(X), 0.1)
X_grid = X_grid.reshape((len(X_grid), 1))
plt.scatter(X, y, color = 'red')
plt.plot(X_grid, lin_reg_2.predict(poly_reg.fit_transform(X_grid)), color = 'blue')
plt.title('Truth or Bluff (Polynomial Regression)')
plt.xlabel('points earned')
plt.ylabel('points obtained')
plt.show()

# %%
# Predicting a new result with Linear Regression
lin_reg.predict(np.array(183).reshape(-1,1))
# Out:
# array([[94.67118644]])

# %%
# Predicting a new result with Polynomial Regression
lin_reg_2.predict(poly_reg.fit_transform(np.array(183).reshape(-1,1)))
# Out:
# array([[92.78282188]])
