# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import import_ipynb

# %%
#La información de estos datos pertenecen a la temporada 2017/2018 de La Liga. 
# Para ver como quedo la tabla de esta temporada vea dentro de la carpeta Info_para_usar y y abra la imagen que se llama 
#Tabla_temporada_2017_2018
Girona2018 = 51
Eibar2018 = 51

# %%
#La información de estos datos pertenecen a la temporada 2017/2018 de La Liga. 
# Para ver como quedo la tabla de esta temporada vea dentro de la carpeta Info_para_usar y y abra la imagen que se llama 
#Tabla_temporada_2018_2019
Girona2019 = 37
Eibar2019 = 47

# %%
#La información de estos datos pertenecen a la temporada 2019/2020 de La Liga. 
# Para ver como quedo la tabla de esta temporada vea dentro de la carpeta Info_para_usar y y abra la imagen que se llama 
#Tabla_temporada_2019_2020
Espanyol2020 = 20
Osasuna2020 = 34
Granada2020 = 38

# %%
GironaTOTAL = Girona2018+Girona2019
EibarTOTAL = Eibar2018 + Eibar2019
EspanyolTOTAL = Espanyol2020
OsasunaTOTAL = Osasuna2020
GranadaTOTAL = Granada2020

indice = np.arange(5)
lista = [ GironaTOTAL, EibarTOTAL, EspanyolTOTAL, OsasunaTOTAL, GranadaTOTAL]
plt.title("Comparación de las sumatorias de las 3 temporadas")
plt.xlabel("Equipo") 
plt.ylabel("Puntos")
y_pos = np.arange(len(lista))
plt.bar(y_pos, lista, color="r", align='center', alpha=0.5)
plt.xticks(indice, ( "GIR", "EIB","ESP", "OSA","GRA"))
plt.show()

# %% [markdown]
# Para esta parte vamos a conocer el equipo mas campeón en cuando juega de Local, lo cúal es importante ya que es un factor que directamente afecta en el resultado según la creencia popular del Football.

# %%
data = pd.read_csv('LaLiga Complete Matches 1995-2020.csv')
data.head(9245)
# Out:
#        Season        Date     HomeTeam     AwayTeam  FTHG  FTAG FTR  HTHG  \
# 0     1995-96    2/9/1995    La Coruna     Valencia     3     0   H   2.0
# 1     1995-96    2/9/1995     Sp Gijon     Albacete     3     0   H   3.0
# 2     1995-96    3/9/1995   Ath Bilbao    Santander     4     0   H   2.0
# 3     1995-96    3/9/1995   Ath Madrid     Sociedad     4     1   H   1.0
# 4     1995-96    3/9/1995        Celta   Compostela     0     1   A   0.0
# 5     1995-96    3/9/1995      Espanol    Salamanca     3     1   H   2.0
# 6     1995-96    3/9/1995       Merida        Betis     1     1   D   1.0
# 7     1995-96    3/9/1995      Sevilla     Tenerife     0     1   A   0.0
# 8     1995-96    3/9/1995   Valladolid    Barcelona     0     2   A   0.0
# 9     1995-96    3/9/1995    Vallecano  Real Madrid     1     5   A   0.0
# 10    1995-96    3/9/1995     Zaragoza       Oviedo     1     0   H   1.0
# 11    1995-96    9/9/1995     Albacete      Sevilla     3     2   H   2.0
# 12    1995-96    9/9/1995    Barcelona       Merida     2     2   D   1.0
# 13    1995-96    9/9/1995        Betis     Zaragoza     3     1   H   2.0
# 14    1995-96    9/9/1995  Real Madrid   Ath Bilbao     1     2   A   0.0
# 15    1995-96   10/9/1995   Compostela    La Coruna     4     0   H   2.0
# 16    1995-96   10/9/1995       Oviedo    Vallecano     2     0   H   1.0
# 17    1995-96   10/9/1995    Salamanca        Celta     0     1   A   0.0
# 18    1995-96   10/9/1995    Santander   Ath Madrid     0     4   A   0.0
#
#       HTAG HTR
# 0      0.0   H
# 1      0.0   H
# 2      0.0   H
# 3      1.0   D
# 4      0.0   D
# 5      1.0   H
# 6      1.0   D
# 7      0.0   D
# 8      0.0   D
# 9      1.0   A
# 10     0.0   H
# 11     1.0   H
# 12     1.0   D
# 13     0.0   H
# 14     0.0   D
# 15     0.0   H
# 16     0.0   H
# 17     0.0   D
# 18     0.0   D
# 19     0.0   H
# 20     2.0   A
# 21     0.0   D
# 22     1.0   A
# 23     2.0   D
# 24     0.0   D
# 25     0.0   H
# 26     0.0   D
# 27     2.0   D
# 28     1.0   D
# 29     1.0   H
# ...    ...  ..
# 9215   0.0   H
# 9216   0.0   D
# 9217   0.0   H
# 9218   1.0   D
# 9219   1.0   A
# 9220   0.0   H
# 9221   0.0   H
# 9222   1.0   D
# 9223   0.0   H
# 9224   1.0   H
# 9225   0.0   H
# 9226   0.0   H
# 9227   0.0   D
# 9228   0.0   D
# 9229   1.0   A
# 9230   0.0   H
# 9231   1.0   A
# 9232   0.0   D
# 9233   0.0   D
# 9234   0.0   D
# 9235   0.0   D
# 9236   0.0   D
# 9237   1.0   D
# 9238   0.0   H
# 9239   1.0   A
# 9240   0.0   H
# 9241   0.0   D
# 9242   0.0   D
# 9243   0.0   D
# 9244   1.0   D
#
# [9245 rows x 10 columns]

# %%
#GIRONA RESULTADOS COMO LOCAL 
numero = 0
GIRvictories = 0
GIRdefeats = 0
GIRdraw = 0
while(numero < 380):
    if(data.HomeTeam[8524 + numero] == 'Girona'):
        if(data.FTR[8524 + numero] == 'H'):
            GIRvictories += 1
        elif(data.FTR[8524 + numero] == 'D'):
            GIRdraw += 1
        elif(data.FTR[8524 + numero] == 'A'):
            GIRdefeats += 1
    numero += 1
numero = 0 
while(numero < 380):
    if(data.HomeTeam[8904 + numero] == 'Girona'):
        if(data.FTR[8904 + numero] == 'H'):
            GIRvictories += 1
        elif(data.FTR[8904 + numero] == 'D'):
            GIRdraw += 1
        elif(data.FTR[8904 + numero] == 'A'):
            GIRdefeats += 1
    numero += 1
numero = 0 
while(numero < 270):
    if(data.HomeTeam[9284 + numero] == 'Girona'):
        if(data.FTR[9284 + numero] == 'H'):
            GIRvictories += 1
        elif(data.FTR[9284 + numero] == 'D'):
            GIRdraw += 1
        elif(data.FTR[9284 + numero] == 'A'):
            GIRdefeats += 1
    numero += 1
#EIBAR
numero = 0
EIBvictories = 0
EIBdefeats = 0
EIBdraw = 0
while(numero < 380):
    if(data.HomeTeam[8524 + numero] == 'Eibar'):
        if(data.FTR[8524 + numero] == 'H'):
            EIBvictories += 1
        elif(data.FTR[8524 + numero] == 'D'):
            EIBdraw += 1
        elif(data.FTR[8524 + numero] == 'A'):
            EIBdefeats += 1
    numero += 1
numero = 0 
while(numero < 380):
    if(data.HomeTeam[8904 + numero] == 'Eibar'):
        if(data.FTR[8904 + numero] == 'H'):
            EIBvictories += 1
        elif(data.FTR[8904 + numero] == 'D'):
            EIBdraw += 1
        elif(data.FTR[8904 + numero] == 'A'):
            EIBdefeats += 1
    numero += 1
numero = 0 
while(numero < 270):
    if(data.HomeTeam[9284 + numero] == 'Eibar'):
        if(data.FTR[9284 + numero] == 'H'):
            EIBvictories += 1
        elif(data.FTR[9284 + numero] == 'D'):
            EIBdraw += 1
        elif(data.FTR[9284 + numero] == 'A'):
            EIBdefeats += 1
    numero += 1
#ESPANYOL
numero = 0
ESPvictories = 0
ESPdefeats = 0
ESPdraw = 0
while(numero < 380):
    if(data.HomeTeam[8524 + numero] == 'Espanyol'):
        if(data.FTR[8524 + numero] == 'H'):
            ESPvictories += 1
        elif(data.FTR[8524 + numero] == 'D'):
            ESPdraw += 1
        elif(data.FTR[8524 + numero] == 'A'):
            ESPdefeats += 1
    numero += 1
numero = 0 
while(numero < 380):
    if(data.HomeTeam[8904 + numero] == 'Espanyol'):
        if(data.FTR[8904 + numero] == 'H'):
            ESPvictories += 1
        elif(data.FTR[8904 + numero] == 'D'):
            ESPdraw += 1
        elif(data.FTR[8904 + numero] == 'A'):
            ESPdefeats += 1
    numero += 1
numero = 0 
while(numero < 270):
    if(data.HomeTeam[9284 + numero] == 'Espanyol'):
        if(data.FTR[9284 + numero] == 'H'):
            ESPvictories += 1
        elif(data.FTR[9284 + numero] == 'D'):
            ESPdraw += 1
        elif(data.FTR[9284 + numero] == 'A'):
            ESPdefeats += 1
    numero += 1
    
#OSASUNA
numero = 0
OSAvictories = 0
OSAdefeats = 0
OSAdraw = 0
while(numero < 380):
    if(data.HomeTeam[8524 + numero] == 'Osasuna'):
        if(data.FTR[8524 + numero] == 'H'):
            OSAvictories += 1
        elif(data.FTR[8524 + numero] == 'D'):
            OSAdraw += 1
        elif(data.FTR[8524 + numero] == 'A'):
            OSAdefeats += 1
    numero += 1
numero = 0 
while(numero < 380):
    if(data.HomeTeam[8904 + numero] == 'Osasuna'):
        if(data.FTR[8904 + numero] == 'H'):
            OSAvictories += 1
        elif(data.FTR[8904 + numero] == 'D'):
            OSAdraw += 1
        elif(data.FTR[8904 + numero] == 'A'):
            OSAdefeats += 1
    numero += 1
numero = 0 
while(numero < 270):
    if(data.HomeTeam[9284 + numero] == 'Osasuna'):
        if(data.FTR[9284 + numero] == 'H'):
            OSAvictories += 1
        elif(data.FTR[9284 + numero] == 'D'):
            OSAdraw += 1
        elif(data.FTR[9284 + numero] == 'A'):
            OSAdefeats += 1
    numero += 1
    
#Granada
numero = 0
GRAvictories = 0
GRAdefeats = 0
GRAdraw = 0
while(numero < 380):
    if(data.HomeTeam[8524 + numero] == 'Granada'):
        if(data.FTR[8524 + numero] == 'H'):
            GRAvictories += 1
        elif(data.FTR[8524 + numero] == 'D'):
            GRAdraw += 1
        elif(data.FTR[8524 + numero] == 'A'):
            GRAdefeats += 1
    numero += 1
numero = 0 
while(numero < 380):
    if(data.HomeTeam[8904 + numero] == 'Granada'):
        if(data.FTR[8904 + numero] == 'H'):
            GRAvictories += 1
        elif(data.FTR[8904 + numero] == 'D'):
            GRAdraw += 1
        elif(data.FTR[8904 + numero] == 'A'):
            GRAdefeats += 1
    numero += 1
numero = 0 
while(numero < 270):
    if(data.HomeTeam[9284 + numero] == 'Granada'):
        if(data.FTR[9284 + numero] == 'H'):
            GRAvictories += 1
        elif(data.FTR[9284 + numero] == 'D'):
            GRAdraw += 1
        elif(data.FTR[9284 + numero] == 'A'):
            GRAdefeats += 1
    numero += 1

# %%
#COMO VISITANTE
#Girona
numero = 0
GIRvictories = 0
GIRdefeats = 0
GIRdraw = 0
while(numero < 380):
    if(data.AwayTeam[8524 + numero] == 'Griona'):
        if(data.FTR[8524 + numero] == 'H'):
            GIRvictories += 1
        elif(data.FTR[8524 + numero] == 'D'):
            GIRdraw += 1
        elif(data.FTR[8524 + numero] == 'A'):
            GIRdefeats += 1
    numero += 1
numero = 0 
while(numero < 380):
    if(data.AwayTeam[8904 + numero] == 'Girona'):
        if(data.FTR[8904 + numero] == 'H'):
            GIRvictories += 1
        elif(data.FTR[8904 + numero] == 'D'):
            GIRdraw += 1
        elif(data.FTR[8904 + numero] == 'A'):
            GIRdefeats += 1
    numero += 1
numero = 0 
while(numero < 270):
    if(data.AwayTeam[9284 + numero] == 'Girona'):
        if(data.FTR[9284 + numero] == 'H'):
            GIRvictories += 1
        elif(data.FTR[9284 + numero] == 'D'):
            GIRdraw += 1
        elif(data.FTR[9284 + numero] == 'A'):
            GIRdefeats += 1
    numero += 1

#Eibar 
numero = 0
EIBvictories = 0
EIBdefeats = 0
EIBdraw = 0
while(numero < 380):
    if(data.AwayTeam[8524 + numero] == 'Eibar'):
        if(data.FTR[8524 + numero] == 'H'):
            EIBvictories += 1
        elif(data.FTR[8524 + numero] == 'D'):
            EIBdraw += 1
        elif(data.FTR[8524 + numero] == 'A'):
            EIBdefeats += 1
    numero += 1
numero = 0 
while(numero < 380):
    if(data.AwayTeam[8904 + numero] == 'Eibar'):
        if(data.FTR[8904 + numero] == 'H'):
            EIBvictories += 1
        elif(data.FTR[8904 + numero] == 'D'):
            EIBdraw += 1
        elif(data.FTR[8904 + numero] == 'A'):
            EIBdefeats += 1
    numero += 1
numero = 0 
while(numero < 270):
    if(data.AwayTeam[9284 + numero] == 'Eibar'):
        if(data.FTR[9284 + numero] == 'H'):
            EIBvictories += 1
        elif(data.FTR[9284 + numero] == 'D'):
            EIBdraw += 1
        elif(data.FTR[9284 + numero] == 'A'):
            EIBdefeats += 1
    numero += 1
    
#Espanyol
numero = 0
ESPvictories = 0
ESPdefeats = 0
ESPdraw = 0
while(numero < 380):
    if(data.AwayTeam[8524 + numero] == 'Espanyol'):
        if(data.FTR[8524 + numero] == 'H'):
            ESPvictories += 1
        elif(data.FTR[8524 + numero] == 'D'):
            ESPdraw += 1
        elif(data.FTR[8524 + numero] == 'A'):
            ESPdefeats += 1
    numero += 1
numero = 0 
while(numero < 380):
    if(data.AwayTeam[8904 + numero] == 'Espanyol'):
        if(data.FTR[8904 + numero] == 'H'):
            ESPvictories += 1
        elif(data.FTR[8904 + numero] == 'D'):
            ESPdraw += 1
        elif(data.FTR[8904 + numero] == 'A'):
            ESPdefeats += 1
    numero += 1
numero = 0 
while(numero < 270):
    if(data.AwayTeam[9284 + numero] == 'Espanyol'):
        if(data.FTR[9284 + numero] == 'H'):
            ESPvictories += 1
        elif(data.FTR[9284 + numero] == 'D'):
            ESPdraw += 1
        elif(data.FTR[9284 + numero] == 'A'):
            ESPdefeats += 1
    numero += 1
    
#OSASUNA
numero = 0
OSAvictories = 0
OSAdefeats = 0
OSAdraw = 0
while(numero < 380):
    if(data.AwayTeam[8524 + numero] == 'Osasuna'):
        if(data.FTR[8524 + numero] == 'H'):
            OSAvictories += 1
        elif(data.FTR[8524 + numero] == 'D'):
            OSAdraw += 1
        elif(data.FTR[8524 + numero] == 'A'):
            SOAdefeats += 1
    numero += 1
numero = 0 
while(numero < 380):
    if(data.AwayTeam[8904 + numero] == 'Osasuna'):
        if(data.FTR[8904 + numero] == 'H'):
            OSAvictories += 1
        elif(data.FTR[8904 + numero] == 'D'):
            OSAdraw += 1
        elif(data.FTR[8904 + numero] == 'A'):
            OSAdefeats += 1
    numero += 1
numero = 0 
while(numero < 270):
    if(data.AwayTeam[9284 + numero] == 'Osasuna'):
        if(data.FTR[9284 + numero] == 'H'):
            OSAvictories += 1
        elif(data.FTR[9284 + numero] == 'D'):
            OSAdraw += 1
        elif(data.FTR[9284 + numero] == 'A'):
            OSAdefeats += 1
    numero += 1
    
#Granada
numero = 0
GRAvictories = 0
GRAdefeats = 0
GRAdraw = 0
while(numero < 380):
    if(data.AwayTeam[8524 + numero] == 'Granada'):
        if(data.FTR[8524 + numero] == 'H'):
            GRAvictories += 1
        elif(data.FTR[8524 + numero] == 'D'):
            GRAdraw += 1
        elif(data.FTR[8524 + numero] == 'A'):
            GRAdefeats += 1
    numero += 1
numero = 0 
while(numero < 380):
    if(data.AwayTeam[8904 + numero] == 'Granada'):
        if(data.FTR[8904 + numero] == 'H'):
            GRAvictories += 1
        elif(data.FTR[8904 + numero] == 'D'):
            GRAdraw += 1
        elif(data.FTR[8904 + numero] == 'A'):
            GRAdefeats += 1
    numero += 1
numero = 0 
while(numero < 270):
    if(data.AwayTeam[9284 + numero] == 'Granada'):
        if(data.FTR[9284 + numero] == 'H'):
            GRAvictories += 1
        elif(data.FTR[9284 + numero] == 'D'):
            GRAdraw += 1
        elif(data.FTR[9284 + numero] == 'A'):
            GRAdefeats += 1
    numero += 1
